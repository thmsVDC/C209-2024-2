# %% [markdown]
# ## Importando pacotes

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
img = Image.open('Images/Bart.png')
plt.imshow(img)

# %%
img_np = np.array(img)
img_np2 = img_np[:,:,:3] #tirar o canal alfa
plt.imshow(img_np2)
print(img_np2.shape)
# Out:
# (298, 200, 3)

# %%
ex = np.zeros(shape=(8, 8 * 3, 3), dtype=np.uint8)
ex[:, :8]   = (255, 0, 0) # todas as linhas, colunas 0:8
ex[:, 8:16] = (0, 255, 0) # todas as linhas, colunas 8:16
ex[:, 16:]  = (0, 0, 255) # todas as linhas, colunas 16:24
ex[0, 0] = (255, 255, 255) # linha 0, coluna 0, todas as páginas
plt.imshow(ex)

# %%
(l, c, p) = img_np.shape

img_avg = np.zeros(shape=(l, c), dtype=np.uint8)
for i in range(l):
    for j in range(c):
        r = float(img_np[i, j, 0])
        g = float(img_np[i, j, 1])
        b = float(img_np[i, j, 2])
        
        img_avg[i, j] = (r + g + b) / 3
        

plt.imshow(img_avg, cmap = 'gray')
print(img_avg.shape)
# Out:
# (298, 200)

# %%
# Média no eixo 2 (páginas). Canal alpha (A) omitido.
# Obs.: Lembrar de converter para np.uint8!
img_avg2 = np.average(img_np[:, :, :3], axis=2)#.astype(np.uint8)
plt.imshow(img_avg2, cmap='gray')
img.save('Images/Bart.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 5
#       3 img_avg2 = np.average(img_np[:, :, :3], axis=2)#.astype(np.uint8)
#       4 plt.imshow(img_avg2, cmap='gray')
# ----> 5 img_avg2.save('Images/Bart.png')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'save'

# %% [markdown]
# # Exercícios propostos

# %% [markdown]
# 1. Utilize um método grayscale e salve a imagem resultante no disco.

# %%
img = Image.open('Images/Bart.png')

img_avg = np.average(img_np[:, :, :3], axis=2)#.astype(np.uint8)
plt.imshow(img_avg, cmap='gray')
img_gray = Image.fromarray(img_avg, mode='L')
img_gray.save('Images/BartGray.png')
